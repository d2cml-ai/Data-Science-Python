# %%
# !pip install openai --quiet
# !pip install PyMuPDF --quiet

# %%
from google.colab import files

# Load PDF
uploaded = files.upload()

# Detect file name
for filename in uploaded.keys():
    pdf_path = filename
print(f"📁 Archivo cargado: {pdf_path}")

# %%
import fitz  # PyMuPDF

def extraer_texto_pdf(ruta_pdf):
    doc = fitz.open(ruta_pdf)
    texto = ""
    for pagina in doc:
        texto += pagina.get_text()
    doc.close()
    return texto

cv_texto = extraer_texto_pdf(pdf_path)
print("✅ Texto extraído del CV:")
print(cv_texto[:5000])  # muestra primeros 1000 caracteres

# %%
from openai import OpenAI
from getpass import getpass

api_key = getpass("🔑 Ingresa tu API key de OpenAI: ").strip()
client = OpenAI(api_key=api_key)

# %%
prompt = f"""
You are an expert in talent acquisition for tech and financial companies.
Analyze the following résumé and extract:

1. Professional experience (company, role, years)
2. Certifications (name, year, issuing organization if mentioned)
3. Mastered technologies (languages, platforms, tools)
4. Signs of inconsistencies or gaps (unclear dates, unsupported certifications)
5. Overall relevance of the profile for a senior data analyst position

CV:
\"\"\"
{cv_texto}
\"\"\"
"""

# %%
response = client.chat.completions.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "You are a specialist in CV analysis for tech/banking recruitment processes."},
        {"role": "user", "content": prompt}
    ],
    temperature=0
)

print("📋 CV Analysis Report:\n")
print(response.choices[0].message.content.strip())

# %%
ideal_profile = """
📌 Position: Senior Data Analyst

🎯 Role Objective:
Lead advanced data analysis to generate strategic insights that support business decision-making, contributing to operational efficiency, profitability, and risk management. Additionally, mentor junior analysts and participate in the definition of data models and executive reporting.

🛠️ Technical Requirements:
- Minimum 5 years of experience in data analysis roles, preferably in banking, insurance, fintech, or tech.
- Advanced proficiency with analysis and visualization tools: SQL, Python (pandas, numpy, matplotlib), Power BI or Tableau.
- Knowledge of version control tools (Git) and ETL processes.
- Experience in relational database modeling.
- Ability to build dashboards and interactive reports for non-technical stakeholders.
- Desirable: experience in predictive modeling or machine learning.

📚 Preferred Certifications:
- Google Data Analytics, Microsoft Data Analyst Associate.
- Certification in agile methodologies: Scrum Master, PMP.
- Certification in statistical analysis or predictive modeling.

💡 Soft Skills:
- Critical thinking and ability to translate data into actionable recommendations.
- Autonomy and leadership: experience guiding or supervising other analysts.
- Effective communication with multidisciplinary teams (business, tech, risk).
- Ability to manage priorities in environments with multiple simultaneous demands.

📈 Main Responsibilities:
- Define and execute processes for extracting, cleaning, and analyzing structured and unstructured data.
- Identify trends, improvement opportunities, and generate early business alerts.
- Automate operational and managerial reports through dashboards.
- Support the construction of prediction, segmentation, or scoring models.
- Document processes and promote best practices in data governance.
- Participate in digital transformation and data-driven decision-making projects.

🎯 Evaluation Criteria (for scoring):
- Experience: up to 30 points
- Technical tools: up to 25 points
- Relevant certifications: up to 15 points
- Soft skills and leadership: up to 20 points
- Added value (bonus): up to 10 points

Expected total score for full fit: 85–100 points
"""

# %%
prompt = f"""
You are a talent acquisition expert for tech positions in banking, insurance, or technology sectors.

Your task is to analyze the following CV and compare it with the ideal profile defined below.

You must perform:
1. Extraction of professional experience (company, role, years).
2. Identification of mastered technical tools (SQL, Python, BI, etc.).
3. Relevant certifications (name, year, issuing entity if provided).
4. Evaluation of soft skills and leadership ability.
5. Comparison with the ideal profile.
6. Numerical scoring per category (see criteria).
7. Total score (scale from 0 to 100) and hiring recommendation.

🎯 Use this result template:

----
🔍 **CV Evaluation Summary**

📌 Experience (____ / 30):
- ...

🛠️ Technical Tools (____ / 25):
- ...

📚 Certifications (____ / 15):
- ...

💬 Soft Skills and Leadership (____ / 20):
- ...

🎁 Added or Differentiating Value (____ / 10):
- ...

📊 **Total Score**: ___ / 100
🎯 **Recommendation**: (Yes / No / Requires technical interview)

📝 General Comments:
- ...
----

🔍 Ideal job profile:

{ideal_profile}

👤 Candidate’s CV:
\"\"\"
{cv_texto}
\"\"\"
"""

# %%
response = client.chat.completions.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "You are a talent acquisition expert who compares CVs against ideal profiles."},
        {"role": "user", "content": prompt}
    ],
    temperature=0
)

print("📋 Report with Comparison and Scoring:\n")
print(response.choices[0].message.content.strip())

# %%
perfil_ideal = """
📌 Position: Marketing Specialist

🎯 Role Objective:
Design, execute, and optimize marketing campaigns that drive brand positioning, demand generation, and customer conversion in both digital and physical environments. The role requires a combination of creative thinking, data analysis, and consumer insight.

🛠️ Technical Requirements:

Minimum of 3 years of experience in digital marketing, ATL/BTL campaigns, or omnichannel strategies.

Proficiency with tools: Google Ads, Meta Business Suite, Google Analytics, Canva, Mailchimp.

Knowledge of SEO, SEM, marketing automation, and conversion funnels.

Ability to manage multiple campaigns and budgets.

Desirable: basic knowledge of graphic design or video editing.

📚 Preferred Certifications:

Certifications in Google Ads, Google Analytics, HubSpot, or Meta Blueprint.

Courses in digital marketing, brand storytelling, or customer journey.

💡 Soft Skills:

Creativity, proactiveness, and constant innovation.

Clear and persuasive communication (oral and written).

Customer focus, empathy, and sensitivity to audiences.

Collaborative work with design, sales, and product teams.

📈 Main Responsibilities:

Plan digital marketing campaigns aligned with business objectives.

Develop visual and written content for social media, email marketing, and blogs.

Measure, analyze, and optimize campaign performance (KPIs: CTR, CPL, ROAS).

Manage budget and report results to the marketing leadership.

Research market trends and conduct competitive benchmarking.

Contribute to brand strategy and customer experience design.

🎯 Evaluation Criteria (for scoring):

Applied marketing experience (up to 30 points)

Mastery of tools and platforms (up to 25 points)

Relevant certifications (up to 15 points)

Creative and communication skills (up to 20 points)

Added value (brand knowledge, storytelling, etc.) (up to 10 points)

Expected total score for full fit: 85–100 points
"""

# %%
prompt = f"""
You are a talent acquisition specialist for marketing positions in consumer goods, services, and technology companies.

Your task is to analyze the following CV and compare it with the ideal profile defined below.

You must perform:
1. Extraction of relevant marketing experience (roles, companies, campaigns, achievements).
2. Tools and platforms mastered (e.g., Google Ads, Canva, Mailchimp, Meta Ads).
3. Certifications obtained (name, year, issuing organization if indicated).
4. Evaluation of soft skills (creativity, communication, empathy).
5. Comparison with the ideal profile and degree of fit.
6. Numerical scoring in 5 categories (see criteria).
7. Total score on a scale from 0–100.
8. Final recommendation: (Yes / No / Requires creative interview).

Use this result template:

----
🎯 **Candidate Evaluation – Marketing Specialist**

📌 Applied marketing experience (____ / 30):
- ...

🛠️ Tools and platforms (____ / 25):
- ...

📚 Certifications (____ / 15):
- ...

🎨 Creative and communication skills (____ / 20):
- ...

🎁 Added value (branding, storytelling, consumer insights) (____ / 10):
- ...

📊 **Total Score**: ____ / 100
📌 **Recommendation**: (Yes / No / Requires creative interview)

📝 Additional comments:
- ...
----

📌 Ideal job profile:

{perfil_ideal}

📎 Candidate’s CV:
\"\"\"
{cv_texto}
\"\"\"
"""

# %%
response = client.chat.completions.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "You are a talent acquisition expert who compares CVs against ideal profiles."},
        {"role": "user", "content": prompt}
    ],
    temperature=0
)

print("📋 Report with comparison and scoring:\n")
print(response.choices[0].message.content.strip())

# %% [markdown]
# ✅ Conclusion: Benefits of this Automation
# Automating CV analysis through Prompt Engineering + language models like GPT-4 generates strategic benefits for both the Human Resources department and the business as a whole:
#
# 🔍 Consistency: More objective and standardized evaluations.
#
# ⏱️ Time savings: Automatic preliminary filtering of large volumes of candidates.
#
# 📊 Structured evaluation: Clear scoring in key categories.
#
# 🧠 In-depth analysis: Not only extracts information, but also compares, interprets, and recommends.
#
# 🎯 Focus on added value: Helps identify candidates aligned with the role’s culture and vision, not just the most "qualified."
#
# This approach takes the selection process to the next level by integrating contextual intelligence and automatic comparative analysis, and it is applicable to various professional, technical, and creative profiles.
